# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14, 10)
plt.rcParams['lines.linewidth'] = 0.15

key = 84

# %%
plt.subplot(411)
plt.title('CASE 1')
plt.xlabel('timestep')
plt.ylabel('power consumption[mV]')
plt.xlim([0, 65000])
df = pd.read_pickle('C:/Workspace/CPA/data/test/1.pkl')
for x in df.iloc[key::256, :].trace:
    plt.plot(x)

plt.subplot(412)
plt.title('CASE 2')
plt.xlabel('timestep')
plt.ylabel('power consumption[mV]')
plt.xlim([0, 65000])
df = pd.read_pickle('C:/Workspace/CPA/data/method1/DPO4032_10_211108-191111.pkl')
for x in df.iloc[key::256, :].trace:
    plt.plot(x)

plt.subplot(413)
plt.title('CASE 3')
plt.xlabel('timestep')
plt.ylabel('power consumption[mV]')
plt.xlim([0, 65000])
df = pd.read_pickle('C:/Workspace/CPA/data/method4/test/DPO4032_10_211112-181147.pkl')
for x in df.iloc[key::256, :].trace:
    plt.plot(x)

plt.subplot(414)
plt.title('CASE 4')
plt.xlabel('timestep')
plt.ylabel('power consumption[mV]')
plt.xlim([0, 65000])
df = pd.read_pickle('C:/Workspace/CPA/data/method2/test/DPO4032_10_211109-121144.pkl')
for x in df.iloc[key::256, :].trace:
    plt.plot(x)

plt.subplots_adjust(left=0.125,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.2,
                    hspace=0.55)
plt.show()
